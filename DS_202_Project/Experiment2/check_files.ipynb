# %% [markdown]
# # Experiment 2 : Data Integrity checks - pbmc1 and pbmc2

# %%
#imports
import pandas as pd

# %% [markdown]
# ## Note : Files of very large size, DO NOT OPEN on standard system

# %%
pbmc10Xv2A = pd.read_csv("/pscratch/sd/s/samarthb/DS_202_Project/scGNN_project/DS_202_Project/Experiment2/Data/Datasets/PBMCbench/10Xv2A_pbmc1/10Xv2A_pbmc1.csv")
pbmc10Xv2B = pd.read_csv("/pscratch/sd/s/samarthb/DS_202_Project/scGNN_project/DS_202_Project/Experiment2/Data/Datasets/PBMCbench/10Xv2B_pbmc1/10Xv2B_pbmc1.csv")

# %%
zheng68k = pd.read_csv("/pscratch/sd/s/samarthb/DS_202_Project/scGNN_project/DS_202_Project/Experiment2/Data/Datasets/Zhengsort/Filtered_DownSampled_SortedPBMC_data.csv")

# %%
pbmc10Xv2A.shape
# Out:
# (23154, 20424)

# %%
pbmc10Xv2B.shape
# Out:
# (23154, 20557)

# %%
zheng68k.shape
# Out:
# (20000, 21953)
